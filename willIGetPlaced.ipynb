# %% [markdown]
# <a href="https://colab.research.google.com/github/Aditya-0I/willIGetPlaced/blob/main/willIGetPlaced.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df=pd.read_csv("https://drive.google.com/uc?export=download&id=1SgXW8NZ7Jgtz4o-K-JEAMv4y0BgNZ231")
df=df.drop('StudentID',axis=1)
df.head(5)
# Out:
#    CGPA  Internships  Projects  Workshops/Certifications  AptitudeTestScore  \
# 0   7.5            1         1                         1                 65
# 1   8.9            0         3                         2                 90
# 2   7.3            1         2                         2                 82
# 3   7.5            1         1                         2                 85
# 4   8.3            1         2                         2                 86
#
#    SoftSkillsRating ExtracurricularActivities PlacementTraining  SSC_Marks  \
# 0               4.4                        No                No         61
# 1               4.0                       Yes               Yes         78
# 2               4.8                       Yes                No         79
# 3               4.4                       Yes               Yes         81
# 4               4.5                       Yes               Yes         74
#
#    HSC_Marks PlacementStatus
# 0         79       NotPlaced
# 1         82          Placed
# 2         80       NotPlaced
# 3         80          Placed
# 4         88          Placed

# %%
df['PlacementStatus'] = df['PlacementStatus'].astype('category')
df['ExtracurricularActivities'] = df['ExtracurricularActivities'].astype('category')
df['PlacementTraining'] = df['PlacementTraining'].astype('category')

df['PlacementStatus'] = df['PlacementStatus'].cat.codes
df['ExtracurricularActivities'] = df['ExtracurricularActivities'].cat.codes
df['PlacementTraining'] = df['PlacementTraining'].cat.codes
df.head(5)
# Out:
#    CGPA  Internships  Projects  Workshops/Certifications  AptitudeTestScore  \
# 0   7.5            1         1                         1                 65
# 1   8.9            0         3                         2                 90
# 2   7.3            1         2                         2                 82
# 3   7.5            1         1                         2                 85
# 4   8.3            1         2                         2                 86
#
#    SoftSkillsRating  ExtracurricularActivities  PlacementTraining  SSC_Marks  \
# 0               4.4                          0                  0         61
# 1               4.0                          1                  1         78
# 2               4.8                          1                  0         79
# 3               4.4                          1                  1         81
# 4               4.5                          1                  1         74
#
#    HSC_Marks  PlacementStatus
# 0         79                0
# 1         82                1
# 2         80                0
# 3         80                1
# 4         88                1

# %%
X=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,y,test_size=0.2)

# %%
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression(random_state=0, solver='lbfgs', max_iter=1000).fit(X_train,Y_train)

Y_pred=clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score

print(confusion_matrix(Y_test,Y_pred))
print(accuracy_score(Y_test,Y_pred))
# Out:
# [[951 177]
#  [185 687]]
# 0.819
